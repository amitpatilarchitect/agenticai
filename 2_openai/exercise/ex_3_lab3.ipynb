# %%
import os
from openai import AsyncOpenAI
from dotenv import load_dotenv
from agents import Agent, Runner, Trace

# %%
instructions = """
You are a Sales Agent at ComplAI. Your goal is to the best email to Amit whose email is amit.patil.architect@gmail.com.
"""

task = """
Follow these steps:

1. Write a basic email to begin
"""

# %%
sales_agent=Agent(name="Sales Agent1", instructions=instructions, model="gpt-5.4-mini")
email=await Runner.run(sales_agent, "Please send an email")
result=email.final_output
print(result)
